# %%
a = 1
print(a)
print(type(a))

b = "hello"
print(b)
print(type(b))

c = 10.5
print(c)
print(type(c))

d = 1j
print(d)
print(type(d))

e = ["a", "b", "c"]
print(e)
print(type(e))

f = ("a", "b", "c")
print(f)
print(type(f))

g = range(5)
print(g)
print(type(g))

h = {"ani", "budi"}
print(h)
print(type(h))

i = {"nama": "ani"}
print(i)
print(type(i))

j = frozenset({"ani", "budi"})
print(j)
print(type(j))

k = True
print(k)
print(type(k))

l = b"hello"
print(l)
print(type(l))

m = bytearray(5)
print(m)
print(type(m))

n = memoryview(bytes(5))
print(n)
print(type(n))

o = None
print(o)
print(type(o))
# Out:
# 1
# <class 'int'>
# hello
# <class 'str'>
# 10.5
# <class 'float'>
# 1j
# <class 'complex'>
# ['a', 'b', 'c']
# <class 'list'>
# ('a', 'b', 'c')
# <class 'tuple'>
# range(0, 5)
# <class 'range'>
# {'budi', 'ani'}
# <class 'set'>
# {'nama': 'ani'}
# <class 'dict'>
# frozenset({'budi', 'ani'})
# <class 'frozenset'>
# True
# <class 'bool'>
# b'hello'
# <class 'bytes'>
# bytearray(b'\x00\x00\x00\x00\x00')
# <class 'bytearray'>
# ...
# <class 'memoryview'>
# None
# <class 'NoneType'>
